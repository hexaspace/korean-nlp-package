# %% [markdown]
# # 마운팅, 패키지 설치

# %%
import os, sys 
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/KoBERT-NER-master
# Out:
# /content/drive/MyDrive/KoBERT-NER-master

# %%
ls
# Out:
# additional-data/  model/          predict.py        sample_pred_in.txt
# data/             model_backup/   preds/            tokenization_kobert.py
# data_loader.py    model_epoch10/  __pycache__/      trainer.py
# LICENSE           mytest.ipynb    README.md         utils.py
# main.py           output          requirements.txt

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 7.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 67.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 63.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 66.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !pip install seqeval
# Out:
# ...
#      |████████████████████████████████| 43 kB 1.3 MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16181 sha256=4205f8cc7de4571e8d6358bd14d8fc4fcd4c7b4f3b30fcdf3dff345a537deb84
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
# Successfully built seqeval
# ...

# %%
# !pip install sentencepiece
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 8.3 MB/s
# ...

# %% [markdown]
# # 학습

# %%
          # !python3 main.py --model_type kobert --do_train --do_eval --write_pred
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Iteration:  55% 1380/2532 [41:40<31:48,  1.66s/it]
# Iteration:  55% 1381/2532 [41:41<31:48,  1.66s/it]
# Iteration:  55% 1382/2532 [41:43<31:48,  1.66s/it]
# Iteration:  55% 1383/2532 [41:45<31:46,  1.66s/it]
# Iteration:  55% 1384/2532 [41:46<31:47,  1.66s/it]
# Iteration:  55% 1385/2532 [41:48<31:46,  1.66s/it]
# Iteration:  55% 1386/2532 [41:49<31:43,  1.66s/it]
# Iteration:  55% 1387/2532 [41:51<31:41,  1.66s/it]
# Iteration:  55% 1388/2532 [41:53<31:41,  1.66s/it]
# Iteration:  55% 1389/2532 [41:54<31:38,  1.66s/it]
# Iteration:  55% 1390/2532 [41:56<31:36,  1.66s/it]
# Iteration:  55% 1391/2532 [41:58<31:32,  1.66s/it]
# Iteration:  55% 1392/2532 [41:59<31:32,  1.66s/it]
# Iteration:  55% 1393/2532 [42:01<31:30,  1.66s/it]
# Iteration:  55% 1394/2532 [42:03<31:29,  1.66s/it]
# Iteration:  55% 1395/2532 [42:04<31:29,  1.66s/it]
# Iteration:  55% 1396/2532 [42:06<31:29,  1.66s/it]
# Iteration:  55% 1397/2532 [42:08<31:27,  1.66s/it]
# ...

# %% [markdown]
# # 테스트

# %%
# !python3 predict.py --input_file "./test/sample_pred_in.txt" --output_file "./test/test_output" --model_dir "./model"
# Out:
# Traceback (most recent call last):
#   File "predict.py", line 7, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 197, in <module>
#     from torch._C import *  # noqa: F403
# RuntimeError: KeyboardInterrupt:

# %%
# !python3 predict.py --input_file "./additional-data/disasterSMS1_135.txt" --output_file "./additional-data/output_disasterSMS1.txt" --model_dir "./model"
# Out:
# Traceback (most recent call last):
#   File "predict.py", line 7, in <module>
#     import torch
#   File "/usr/local/lib/python3.7/dist-packages/torch/__init__.py", line 684, in <module>
#     import torch.nn.quantizable
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/quantizable/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/quantizable/modules/__init__.py", line 1, in <module>
#     from .activation import MultiheadAttention
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/quantizable/modules/activation.py", line 4, in <module>
#     import torch.nn.quantized as nnq
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/quantized/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/quantized/modules/__init__.py", line 4, in <module>
# ...

# %%
# !python3 predict.py --input_file "./additional-data/test.txt" --output_file "./additional-data/output_test.txt" --model_dir "./model"
# Out:
# Traceback (most recent call last):
#   File "predict.py", line 9, in <module>
#     from transformers import AutoModelForTokenClassification
# ModuleNotFoundError: No module named 'transformers'

# %%
ls
# Out:
# additional-data/  model/          predict.py        sample_pred_in.txt
# data/             model_backup/   preds/            tokenization_kobert.py
# data_loader.py    model_epoch10/  __pycache__/      trainer.py
# LICENSE           mytest.ipynb    README.md         utils.py
# main.py           output          requirements.txt

# %%
cd /content/drive/MyDrive/KoBERT-NER-master
# Out:
# /content/drive/MyDrive/KoBERT-NER-master
